-- %% [markdown]
-- # **Cyclistic Case Study**
--
-- ## **<u>How Does a Bike-Share Navigate Speedy Success?</u>**
--
-- **(Part of Google Data Analytics Certification)**
--
-- This case study is focused on the customer behavior of a bike-share company named **Cyslictic** based in Chicago, USA. **Microsoft Excel** is used for data cleaning and **Microsoft SQL Server** is used for data analysis. Data visualization is done with **Tableau.**

-- %% [markdown]
--
--
-- ## **About the company**
--
-- ![](attachment:image.png)
--
-- In 2016, Cyclistic launched a successful bike-share offering. Since then, the program has grown to a fleet of 5,824 bicycles that are tracked and locked into a network of 692 stations across Chicago. The bikes can be unlocked from one station and returned to any other station in the system anytime.
--
--  Until now, Cyclistic’s marketing strategy relied on building general awareness and appealing to broad consumer segments. One approach that helped make these things possible was the flexibility of its pricing plans: single-ride passes, full-day passes, and annual memberships. Customers who purchase single-ride or full-day passes are referred to as casual riders. Customers who purchase annual memberships are Cyclistic members.
--
-- ## **Objective**
--
-- Provide the marketing team with insights about customer behavior in order to design effective marketing strategies aimed at converting casual members into annual members.
--
-- We are going to focus on these questions :
--
-- > 1\. How do annual members and casual riders use Cyclistic bikes differently?
--
-- > 2\. Why would casual riders buy Cyclistic annual memberships?

-- %% [markdown]
-- ## **Tools Used**
--
-- - Microsoft Excel and Power Query  *-- _for data cleaning and data manipulation_*
-- - Microsoft SQL Server  *-- for data analysis with SQL*
-- - Azure Data Studio  *-- for creating this notebook*
-- - Tableau Desktop  *-- for data visualization*

-- %% [markdown]
-- ## **About the Dataset**
--
-- - Here is the [Cyclistic Trip Dataset](https://divvy-tripdata.s3.amazonaws.com/index.html).
-- - Note : The datasets have a different name because Cyclistic is a fictional company.The data has been made available by Motivate International Inc. under this [license](https://ride.divvybikes.com/data-license-agreement).
-- - We are going to use 12 months of data from April 2021 to March 2022 for the analysis.
-- - The datasets are CSV files that contain the following columns:
--     - <span style="background-color: transparent; color: var(--ricos-custom-p-color,unset); font-family: var(--ricos-custom-p-font-family,unset); font-size: var(--ricos-custom-p-font-size,unset); font-style: var(--ricos-custom-p-font-style,unset); font-weight: var(--ricos-custom-p-font-weight,unset);">RIDE_ID <em>-- A unique id for each ride</em></span>
--     - <span style="background-color: transparent; color: var(--ricos-custom-p-color,unset); font-family: var(--ricos-custom-p-font-family,unset); font-size: var(--ricos-custom-p-font-size,unset); font-style: var(--ricos-custom-p-font-style,unset); font-weight: var(--ricos-custom-p-font-weight,unset);">RIDEABLE_TYPE <em>-- The type of bike used for the ride</em></span>
--     - <span style="background-color: transparent; color: var(--ricos-custom-p-color,unset); font-family: var(--ricos-custom-p-font-family,unset); font-size: var(--ricos-custom-p-font-size,unset); font-style: var(--ricos-custom-p-font-style,unset); font-weight: var(--ricos-custom-p-font-weight,unset);">STARTED_AT <em>-- Starting date and time of the ride</em></span>
--     - <span style="background-color: transparent; color: var(--ricos-custom-p-color,unset); font-family: var(--ricos-custom-p-font-family,unset); font-size: var(--ricos-custom-p-font-size,unset); font-style: var(--ricos-custom-p-font-style,unset); font-weight: var(--ricos-custom-p-font-weight,unset);">ENDED_AT <em>-- Ending date and time of the ride</em></span>
--     - <span style="background-color: transparent; color: var(--ricos-custom-p-color,unset); font-family: var(--ricos-custom-p-font-family,unset); font-size: var(--ricos-custom-p-font-size,unset); font-style: var(--ricos-custom-p-font-style,unset); font-weight: var(--ricos-custom-p-font-weight,unset);">START_STATION_NAME <em>-- Starting station name</em></span>
--     - <span style="background-color: transparent; color: var(--ricos-custom-p-color,unset); font-family: var(--ricos-custom-p-font-family,unset); font-size: var(--ricos-custom-p-font-size,unset); font-style: var(--ricos-custom-p-font-style,unset); font-weight: var(--ricos-custom-p-font-weight,unset);">START_STATION_ID <em>-- Starting station id</em></span>
--     - <span style="background-color: transparent; color: var(--ricos-custom-p-color,unset); font-family: var(--ricos-custom-p-font-family,unset); font-size: var(--ricos-custom-p-font-size,unset); font-style: var(--ricos-custom-p-font-style,unset); font-weight: var(--ricos-custom-p-font-weight,unset);">END_STATION_NAME <em>-- Ending station name</em></span>
--     - <span style="background-color: transparent; color: var(--ricos-custom-p-color,unset); font-family: var(--ricos-custom-p-font-family,unset); font-size: var(--ricos-custom-p-font-size,unset); font-style: var(--ricos-custom-p-font-style,unset); font-weight: var(--ricos-custom-p-font-weight,unset);">END_STATION_ID <em>-- Ending station id</em></span>
--     - <span style="background-color: transparent; color: var(--ricos-custom-p-color,unset); font-family: var(--ricos-custom-p-font-family,unset); font-size: var(--ricos-custom-p-font-size,unset); font-style: var(--ricos-custom-p-font-style,unset); font-weight: var(--ricos-custom-p-font-weight,unset);">START_LAT <em>-- Latitude of starting station</em></span>
--     - <span style="background-color: transparent; color: var(--ricos-custom-p-color,unset); font-family: var(--ricos-custom-p-font-family,unset); font-size: var(--ricos-custom-p-font-size,unset); font-style: var(--ricos-custom-p-font-style,unset); font-weight: var(--ricos-custom-p-font-weight,unset);">START_LNG <em>-- Longitude of starting station</em></span>
--     - <span style="background-color: transparent; color: var(--ricos-custom-p-color,unset); font-family: var(--ricos-custom-p-font-family,unset); font-size: var(--ricos-custom-p-font-size,unset); font-style: var(--ricos-custom-p-font-style,unset); font-weight: var(--ricos-custom-p-font-weight,unset);">END_LAT <em>-- Latitude of ending station</em></span>
--     - <span style="background-color: transparent; color: var(--ricos-custom-p-color,unset); font-family: var(--ricos-custom-p-font-family,unset); font-size: var(--ricos-custom-p-font-size,unset); font-style: var(--ricos-custom-p-font-style,unset); font-weight: var(--ricos-custom-p-font-weight,unset);">END_LNG <em>-- Longitude of ending station</em></span>
--     - <span style="background-color: transparent; color: var(--ricos-custom-p-color,unset); font-family: var(--ricos-custom-p-font-family,unset); font-size: var(--ricos-custom-p-font-size,unset); font-style: var(--ricos-custom-p-font-style,unset); font-weight: var(--ricos-custom-p-font-weight,unset);">MEMBER_CASUAL <em>-- Defines whether the customer is a "member" or a "casual"</em></span>

-- %% [markdown]
-- ## **Data Cleaning**
--
-- - The datasets are loaded into Power Query.
-- - Made sure that the data types of each column were appopriate.
-- - Removed null values and duplicate values from the data.
-- - Created a column named _'ride\_length'_ by subtracting the '_started\_at'_ column from the _'ended\_at'_ column and formatted as hh:mm:ss using _Format \> Cells \> Time \> 13:33:55._
-- - Created a column named _'weekday'_ and retrieved the weekday from the datetime using the 'WEEKDAY' command.
-- - Removed the columns _'start\_station\_id', 'end\_station\_id', 'start\_lng', 'start\_lat', 'end\_lng', 'end\_lat'_

-- %% [markdown]
-- ## **Data Analysis**
--
-- - The whole SQL query is available in my _[Github repository](https://github.com/ajaikumar-a/Cyclistic-Case-Study/blob/main/SQL_query.sql)_.
-- - Created a new database named _Cyclistic_ in SQL Server.
-- - The 12 tables are loaded into SQL Server under the database _Cyclistic._

-- %% [markdown]
-- > ### _Selecting the Cyclistic database_

-- %%
-- Selecting the Cyclistic database 
USE Cyclistic;
-- Out:
-- Commands completed successfully.
-- Total execution time: 00:00:00.002

-- %% [markdown]
-- > ### _Creating a  table called 'bikeshare' by combining all the 12 tables using UNION_

-- %%
-- Combining the tables using UNION 
SELECT * INTO bikeshare
FROM (
  SELECT 
    *
  FROM
    [april2021]
UNION
  SELECT 
    *
  FROM
    [may2021]
UNION
  SELECT 
    *
  FROM
    [june2021]
UNION
  SELECT 
    *
  FROM
    [july2021]
UNION
  SELECT 
    *
  FROM
    [aug2021]
UNION
  SELECT 
    *
  FROM
    [sept2021]
UNION
  SELECT 
    *
  FROM
    [oct2021]
UNION
  SELECT 
    *
  FROM
    [nov2021]
UNION
  SELECT 
    *
  FROM
    [dec2021]
UNION
  SELECT 
    *
  FROM
    [jan2022]
UNION
  SELECT 
    *
  FROM
    [feb2022]
UNION
  SELECT 
    *
  FROM
    [mar2022]
) t
-- Out:
-- (4641394 rows affected)
-- Total execution time: 00:00:59.687

-- %% [markdown]
-- > ### _Removing the records with 'NULL' and '00:00:00' ride\_length_

-- %%
-- Removing the records with NULL and 00:00:00 ride_length
DELETE 
FROM
  bikeshare
WHERE
  ride_length IS NULL OR 
  ride_length = '00:00:00'
-- Out:
-- (32333 rows affected)
-- Total execution time: 00:00:01.920

-- %% [markdown]
-- > ### _Finding the number of rides per casual and annual members_

-- %%
-- Finding the number of rides per casual and annual members
SELECT 
  member_casual,
  COUNT(ride_id) no_of_rides 
FROM
  bikeshare
GROUP BY
  member_casual
-- Out:
-- (2 rows affected)
-- Total execution time: 00:00:03.714
-- <table><tr><th>member_casual</th><th>no_of_rides</th></tr><tr><td>member</td><td>2574966</td></tr><tr><td>casual</td><td>2034095</td></tr></table>

-- %% [markdown]
-- We can see that the annual members are having more number of rides than casual members.

-- %% [markdown]
-- > ### _Finding the number of rides per weekday_

-- %%
-- Finding the number of rides per weekday
SELECT 
  weekday,
  COUNT(ride_id) weekday_rides
FROM 
  bikeshare
GROUP BY
  weekday
ORDER BY
  weekday_rides DESC;
-- Out:
-- (7 rows affected)
-- Total execution time: 00:00:03.763
-- <table><tr><th>weekday</th><th>weekday_rides</th></tr><tr><td>Saturday</td><td>803184</td></tr><tr><td>Sunday</td><td>713031</td></tr><tr><td>Friday</td><td>650330</td></tr><tr><td>Wednesday</td><td>629311</td></tr><tr><td>Tuesday</td><td>612753</td></tr><tr><td>Thursday</td><td>612316</td></tr><tr><td>Monday</td><td>588136</td></tr></table>

-- %% [markdown]
-- > ### _Finding the total number of rides_

-- %%
-- finding the total number of rides
SELECT
  COUNT(ride_id) total_rides 
FROM
  bikeshare;


-- finding the number of round trips
SELECT
  COUNT(ride_id) round_trips
FROM
  bikeshare
WHERE
  start_station_name = end_station_name;


-- finding the number of non-round trips 
SELECT
  COUNT(ride_id) non_round_trips
FROM 
  bikeshare
WHERE
  start_station_name <> end_station_name;
-- Out:
-- (1 row affected)
-- (1 row affected)
-- (1 row affected)
-- Total execution time: 00:00:08.614
-- <table><tr><th>total_rides</th></tr><tr><td>4609061</td></tr></table>
-- <table><tr><th>round_trips</th></tr><tr><td>300985</td></tr></table>
-- <table><tr><th>non_round_trips</th></tr><tr><td>4308076</td></tr></table>

-- %% [markdown]
-- > ### _Finding the number of round trips per route_

-- %%
-- finding the number of round trips per route
SELECT
  start_station_name,
  end_station_name,
  COUNT(ride_id) round_trips_per_route 
FROM
  bikeshare
WHERE
  start_station_name = end_station_name
GROUP BY
  start_station_name,
  end_station_name
ORDER BY
  round_trips_per_route DESC;

-- %% [markdown]
-- > ### _Finding the number of non-round trips per route_

-- %%
-- finding the number of non-round trips per route
SELECT
  start_station_name,
  end_station_name,
  COUNT(ride_id) non_round_trips_per_route 
FROM
  bikeshare
WHERE
  start_station_name != end_station_name
GROUP BY
  start_station_name,
  end_station_name
ORDER BY
  non_round_trips_per_route DESC;

-- %% [markdown]
-- > ### _Finding the number of round trips and non-round trips by annual members and casual members_

-- %%
-- finding the number of round trips by annual and casual members
SELECT
  member_casual,
  COUNT(ride_id) round_trips 
FROM 
  bikeshare
WHERE
  start_station_name = end_station_name
GROUP BY 
  member_casual

-- finding the number of non-round trips by annual and casual members
SELECT
  member_casual,
  COUNT(ride_id) non_round_trips 
FROM 
  bikeshare
WHERE
  start_station_name <> end_station_name
GROUP BY 
  member_casual
-- Out:
-- (2 rows affected)
-- (2 rows affected)
-- Total execution time: 00:00:10.791
-- <table><tr><th>member_casual</th><th>round_trips</th></tr><tr><td>member</td><td>89336</td></tr><tr><td>casual</td><td>211649</td></tr></table>
-- <table><tr><th>member_casual</th><th>non_round_trips</th></tr><tr><td>member</td><td>2485630</td></tr><tr><td>casual</td><td>1822446</td></tr></table>

-- %% [markdown]
-- > ### _Finding the average ride\_length_

-- %%
-- finding the average ride_length
SELECT
  CAST(CAST(AVG(CAST(CAST(ride_length as datetime) as float)) as datetime) as time) avg_ride_length
FROM
  bikeshare
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:02.679
-- <table><tr><th>avg_ride_length</th></tr><tr><td>00:19:49.8166667</td></tr></table>

-- %% [markdown]
-- > ###
-- >
-- > - _Finding the average ride\_length of round trips_

-- %%
--finding the average ride_length of round trips
SELECT
  CAST(CAST(AVG(CAST(CAST(ride_length as datetime) as float)) as datetime) as time) avg_round_trip_dur 
FROM
  bikeshare
WHERE
  start_station_name = end_station_name;
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:04.269
-- <table><tr><th>avg_round_trip_dur</th></tr><tr><td>00:40:05.8800000</td></tr></table>

-- %% [markdown]
-- > ###
-- >
-- > - _Finding the average ride\_length of non-round trips_

-- %%
--finding the average ride_length of non-round trips
SELECT
  CAST(CAST(AVG(CAST(CAST(ride_length as datetime) as float)) as datetime) as time) avg_non_round_trip_dur 
FROM
  bikeshare
WHERE
  start_station_name != end_station_name;
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:06.633
-- <table><tr><th>avg_non_round_trip_dur</th></tr><tr><td>00:18:24.8566667</td></tr></table>

-- %% [markdown]
-- > ### _Finding the TOP 50 routes_

-- %%
-- finding the TOP 50 routes 
SELECT TOP 50
  CONCAT(start_station_name, ' - ', end_station_name) route,
  COUNT(ride_id) trips_per_route 
FROM
  bikeshare 
GROUP BY
 CONCAT(start_station_name, ' - ', end_station_name)
ORDER BY
  trips_per_route DESC;

-- %% [markdown]
-- > ###
-- >
-- > - _Finding the TOP 50 routes with round trips_

-- %%
-- finding the TOP 50 routes with round trips 
SELECT TOP 50
  CONCAT(start_station_name, ' - ', end_station_name) route,
  COUNT(ride_id) round_trips_per_route 
FROM
  bikeshare
WHERE
  start_station_name = end_station_name 
GROUP BY
 CONCAT(start_station_name, ' - ', end_station_name)
ORDER BY
  round_trips_per_route DESC;

-- %% [markdown]
-- > ###
-- >
-- > - _Finding the TOP 50 routes with non-round trips_

-- %%
-- finding the TOP 50 routes with non-round trips 
SELECT TOP 50
  CONCAT(start_station_name, ' - ', end_station_name) route,
  COUNT(ride_id) non_round_trips_per_route 
FROM
  bikeshare
WHERE
  start_station_name != end_station_name 
GROUP BY
 CONCAT(start_station_name, ' - ', end_station_name)
ORDER BY
  non_round_trips_per_route DESC;

-- %% [markdown]
-- > ### _Finding the distribution of rideable\_type_

-- %%
-- finding the distribution of rideable_type
SELECT
  member_casual,
  rideable_type,
  COUNT(ride_id) no_of_rides 
FROM
  bikeshare
GROUP BY
  member_casual,
  rideable_type
-- Out:
-- (5 rows affected)
-- Total execution time: 00:00:05.997
-- <table><tr><th>member_casual</th><th>rideable_type</th><th>no_of_rides</th></tr><tr><td>member</td><td>electric_bike</td><td>601923</td></tr><tr><td>member</td><td>classic_bike</td><td>1973043</td></tr><tr><td>casual</td><td>docked_bike</td><td>302565</td></tr><tr><td>casual</td><td>classic_bike</td><td>1246162</td></tr><tr><td>casual</td><td>electric_bike</td><td>485368</td></tr></table>

-- %% [markdown]
-- > ### _Finding the distribution of rideable\_type and member\_casual_

-- %%
-- finding the distribution of rideable_type and member_casual in round trips
SELECT
  member_casual,
  rideable_type,
  COUNT(ride_id) round_trips 
FROM 
  bikeshare
WHERE
  start_station_name = end_station_name
GROUP BY
  member_casual,
  rideable_type
ORDER BY 
  round_trips DESC;

-- finding the distribution of rideable_type and member_casual in non-round trips
  SELECT
  member_casual,
  rideable_type,
  COUNT(ride_id) non_round_trips 
FROM 
  bikeshare
WHERE
  start_station_name <> end_station_name
GROUP BY
  member_casual,
  rideable_type
ORDER BY 
  non_round_trips DESC;
-- Out:
-- (5 rows affected)
-- (5 rows affected)
-- Total execution time: 00:00:13.954
-- <table><tr><th>member_casual</th><th>rideable_type</th><th>round_trips</th></tr><tr><td>casual</td><td>classic_bike</td><td>112723</td></tr><tr><td>member</td><td>classic_bike</td><td>69827</td></tr><tr><td>casual</td><td>docked_bike</td><td>60812</td></tr><tr><td>casual</td><td>electric_bike</td><td>38114</td></tr><tr><td>member</td><td>electric_bike</td><td>19509</td></tr></table>
-- <table><tr><th>member_casual</th><th>rideable_type</th><th>non_round_trips</th></tr><tr><td>member</td><td>classic_bike</td><td>1903216</td></tr><tr><td>casual</td><td>classic_bike</td><td>1133439</td></tr><tr><td>member</td><td>electric_bike</td><td>582414</td></tr><tr><td>casual</td><td>electric_bike</td><td>447254</td></tr><tr><td>casual</td><td>docked_bike</td><td>241753</td></tr></table>

-- %% [markdown]
-- > ### _Finding the distribution of casual and annual members across the year_

-- %%
-- finding the distribution of casual and annual members across the year
SELECT
  member_casual,
  CONCAT(DATEPART(MONTH, started_at), ' ', DATEPART(YEAR, started_at)) mon_year,
  COUNT(ride_id) rides 
FROM
  bikeshare
GROUP BY
  member_casual,
  concat(DATEPART(MONTH, started_at), ' ', DATEPART(YEAR, started_at))
ORDER BY
  rides DESC;

-- %% [markdown]
-- > ###
-- >
-- > - _Finding the distribution of casual members across the year_

-- %%
-- finding the distribution of casual members across the year
SELECT
  member_casual,
  CONCAT(DATEPART(MONTH, started_at), ' ', DATEPART(YEAR, started_at)) mon_year,
  COUNT(ride_id) rides 
FROM
  bikeshare
WHERE
  member_casual = 'casual'
GROUP BY
  member_casual,
  concat(DATEPART(MONTH, started_at), ' ', DATEPART(YEAR, started_at))
ORDER BY
  rides DESC;
-- Out:
-- (12 rows affected)
-- Total execution time: 00:00:05.281
-- <table><tr><th>member_casual</th><th>mon_year</th><th>rides</th></tr><tr><td>casual</td><td>7 2021</td><td>367272</td></tr><tr><td>casual</td><td>8 2021</td><td>339604</td></tr><tr><td>casual</td><td>6 2021</td><td>302289</td></tr><tr><td>casual</td><td>9 2021</td><td>291388</td></tr><tr><td>casual</td><td>5 2021</td><td>216823</td></tr><tr><td>casual</td><td>10 2021</td><td>188153</td></tr><tr><td>casual</td><td>4 2021</td><td>119860</td></tr><tr><td>casual</td><td>11 2021</td><td>69564</td></tr><tr><td>casual</td><td>3 2022</td><td>66735</td></tr><tr><td>casual</td><td>12 2021</td><td>44853</td></tr><tr><td>casual</td><td>2 2022</td><td>15033</td></tr><tr><td>casual</td><td>1 2022</td><td>12521</td></tr></table>

-- %% [markdown]
-- > ###
-- >
-- > - _Finding the distribution of annual members across the year_

-- %%
-- finding the distribution of annual members across the year
SELECT
  member_casual,
  CONCAT(DATEPART(MONTH, started_at), ' ', DATEPART(YEAR, started_at)) mon_year,
  COUNT(ride_id) rides 
FROM
  bikeshare
WHERE
  member_casual = 'member'
GROUP BY
  member_casual,
  CONCAT(DATEPART(MONTH, started_at), ' ', DATEPART(YEAR, started_at))
ORDER BY
  rides DESC;
-- Out:
-- (12 rows affected)
-- Total execution time: 00:00:05.963
-- <table><tr><th>member_casual</th><th>mon_year</th><th>rides</th></tr><tr><td>member</td><td>8 2021</td><td>329892</td></tr><tr><td>member</td><td>9 2021</td><td>325227</td></tr><tr><td>member</td><td>7 2021</td><td>319750</td></tr><tr><td>member</td><td>6 2021</td><td>301748</td></tr><tr><td>member</td><td>10 2021</td><td>286046</td></tr><tr><td>member</td><td>5 2021</td><td>234155</td></tr><tr><td>member</td><td>11 2021</td><td>184157</td></tr><tr><td>member</td><td>4 2021</td><td>176196</td></tr><tr><td>member</td><td>3 2022</td><td>147447</td></tr><tr><td>member</td><td>12 2021</td><td>130110</td></tr><tr><td>member</td><td>2 2022</td><td>73245</td></tr><tr><td>member</td><td>1 2022</td><td>66993</td></tr></table>

-- %% [markdown]
-- We can see that June 2021, July 2021, August 2021, and September 2021 are the best performing months since these months consist of the highest number of rides by both annual and casual members.
--
-- On the other hand, December 2021, January 2022, February 2022, and March 2022 are the underperforming months since these months have the lowest number of rides by annual and casual members.

-- %% [markdown]
-- > ### _Best performing months_

-- %%
-- combining the best performing months into a table
SELECT
  *
INTO best_months 
FROM
(  SELECT 
    *
  FROM
    [june2021]
UNION
  SELECT 
    *
  FROM
    [july2021]
UNION
  SELECT 
    *
  FROM
    [aug2021]
UNION
  SELECT 
    *
  FROM
    [sept2021]) b
-- Out:
-- (2596658 rows affected)
-- Total execution time: 00:00:29.031

-- %% [markdown]
-- > ###
-- >
-- > - _Finding the distribution of weekday rides across the best performing months_

-- %%
-- finding the distribution of weeekday rides across the best performing months 
SELECT
  member_casual,
  weekday,
  COUNT(ride_id) day_rides 
FROM
  best_months 
GROUP BY
  member_casual,
  weekday
ORDER BY
  day_rides DESC;
-- Out:
-- (14 rows affected)
-- Total execution time: 00:00:02.996
-- <table><tr><th>member_casual</th><th>weekday</th><th>day_rides</th></tr><tr><td>casual</td><td>Saturday</td><td>286343</td></tr><tr><td>casual</td><td>Sunday</td><td>249214</td></tr><tr><td>member</td><td>Wednesday</td><td>205584</td></tr><tr><td>member</td><td>Thursday</td><td>203811</td></tr><tr><td>member</td><td>Tuesday</td><td>195107</td></tr><tr><td>casual</td><td>Friday</td><td>189912</td></tr><tr><td>member</td><td>Friday</td><td>182708</td></tr><tr><td>member</td><td>Saturday</td><td>174034</td></tr><tr><td>member</td><td>Monday</td><td>169359</td></tr><tr><td>member</td><td>Sunday</td><td>158041</td></tr><tr><td>casual</td><td>Thursday</td><td>157518</td></tr><tr><td>casual</td><td>Wednesday</td><td>144586</td></tr><tr><td>casual</td><td>Monday</td><td>143096</td></tr><tr><td>casual</td><td>Tuesday</td><td>137345</td></tr></table>

-- %% [markdown]
-- We can see that the **weekends** have more rides in the case of **casual** members and the **initial days of the week** have more rides in the case of **annual** members.

-- %% [markdown]
-- > ###
-- >
-- > - _Finding the distribution of 'rideable\_type' and 'member\_casual' across the best performing months_

-- %%
-- finding the distribution of rideable_type and member_casual across the best performing months 
SELECT
  member_casual,
  rideable_type,
  COUNT(ride_id) rides 
FROM
  best_months 
GROUP BY
  member_casual,
  rideable_type   
ORDER BY
  rides DESC;
-- Out:
-- (5 rows affected)
-- Total execution time: 00:00:03.153
-- <table><tr><th>member_casual</th><th>rideable_type</th><th>rides</th></tr><tr><td>member</td><td>classic_bike</td><td>1050347</td></tr><tr><td>casual</td><td>classic_bike</td><td>851890</td></tr><tr><td>casual</td><td>electric_bike</td><td>266308</td></tr><tr><td>member</td><td>electric_bike</td><td>238297</td></tr><tr><td>casual</td><td>docked_bike</td><td>189816</td></tr></table>

-- %% [markdown]
-- > - _Finding the average ride\_length per member\_casual and weekday of the best months_

-- %%
-- finding the average ride_length per member_casual and weekday
SELECT
  member_casual,
  weekday,
  CAST(CAST(AVG(CAST(CAST(ride_length as datetime) as float)) as datetime) as time) avg_ride_length_per_members 
FROM
  bikeshare
GROUP BY
  member_casual,
  weekday
ORDER BY
  avg_ride_length_per_members DESC;
-- Out:
-- (14 rows affected)
-- Total execution time: 00:00:06.695
-- ...

-- %% [markdown]
-- > ### _Worst performing months_

-- %%
-- creating a table for the worst performing months 
SELECT 
  *
INTO worst_months 
FROM
(SELECT 
    *
  FROM
    [dec2021]
UNION
  SELECT 
    *
  FROM
    [jan2022]
UNION
  SELECT 
    *
  FROM
    [feb2022]
UNION
  SELECT 
    *
  FROM
    [mar2022]) w
-- Out:
-- (561660 rows affected)
-- Total execution time: 00:00:06.534

-- %% [markdown]
-- > ###
-- >
-- > - _Finding the distribution of weekday rides across the worst performing months_

-- %%
-- finding the distribution of weekday rides across the worst performing months
SELECT 
  member_casual,
  weekday,
  COUNT(ride_id) weekday_rides
FROM
  worst_months
GROUP BY
  member_casual,
  weekday
ORDER BY 
  weekday_rides DESC;
-- Out:
-- (14 rows affected)
-- Total execution time: 00:00:01.033
-- <table><tr><th>member_casual</th><th>weekday</th><th>weekday_rides</th></tr><tr><td>member</td><td>Wednesday</td><td>75622</td></tr><tr><td>member</td><td>Thursday</td><td>71227</td></tr><tr><td>member</td><td>Tuesday</td><td>67391</td></tr><tr><td>member</td><td>Monday</td><td>64992</td></tr><tr><td>member</td><td>Friday</td><td>54995</td></tr><tr><td>member</td><td>Saturday</td><td>44110</td></tr><tr><td>member</td><td>Sunday</td><td>43342</td></tr><tr><td>casual</td><td>Saturday</td><td>24096</td></tr><tr><td>casual</td><td>Sunday</td><td>23410</td></tr><tr><td>casual</td><td>Wednesday</td><td>20874</td></tr><tr><td>casual</td><td>Monday</td><td>20570</td></tr><tr><td>casual</td><td>Thursday</td><td>19675</td></tr><tr><td>casual</td><td>Friday</td><td>16837</td></tr><tr><td>casual</td><td>Tuesday</td><td>14519</td></tr></table>

-- %% [markdown]
-- - Annual members are having more rides than casual members. However, the number of rides is comparatively lower than that of the best-performing months.
-- - The weekends are not having as much number of rides as the best-performing months.

-- %% [markdown]
-- ## **Data Visualization**

-- %% [markdown]
-- - Here is the link to my [Tableau Public](https://public.tableau.com/app/profile/ajaikumar/viz/CyclisticCaseStudy2_16602351046490/Sheet11) profile

-- %% [markdown]
-- ![Screenshot 2022-08-12 160310.png](attachment:Screenshot2022-08-12160310.png)

-- %% [markdown]
-- - The majority of the rides are by annual members with 55.87% of the total rides.

-- %% [markdown]
-- ![No.of Rides per Weekday.png](attachment:No.ofRidesperWeekday.png)

-- %% [markdown]
-- - We can see that the weekends are having more rides than the other days of the week.

-- %% [markdown]
-- ![Distribution of Rides by Annual and Members Across the Year.png](attachment:DistributionofRidesbyAnnualandMembersAcrosstheYear.png)

-- %% [markdown]
-- - June 2021, July 2021, August 2021, and September 2021 are the months with more rides for casual and annual members.
-- - Annual members are having comparatively more rides than casual members for the other months.

-- %% [markdown]
-- ![Screenshot 2022-08-12 160434.png](attachment:Screenshot2022-08-12160434.png)

-- %% [markdown]
-- - Classic bikes are preferred for 69.85% of the rides with 3,219,205 rides.
-- - Electric bikes are preferred for 23.59% of the rides with 1,087,291 rides.
-- - Docked bikes are preferred for 6.56% of the rides with 302,565 rides.

-- %% [markdown]
-- ![Top 50 Non-Round Trips Per Route.png](attachment:Top50Non-RoundTripsPerRoute.png)

-- %% [markdown]
-- ![Top 50 Round Trips Per Route.png](attachment:Top50RoundTripsPerRoute.png)

-- %% [markdown]
-- > ### **Best Performing Months**

-- %% [markdown]
-- ![No.of Rides by Member_Casual Across the Weekdays of the Best Performing Months.png](attachment:No.ofRidesbyMember_CasualAcrosstheWeekdaysoftheBestPerformingMonths.png)

-- %% [markdown]
-- - In the case of casual members, the weekends are having more rides than the annual members but other days of the week are having a much lower number of rides across the best months.
-- - In the case of annual members, the middle of the week is having more rides and it seems to decline towards the end of the week and the beginning of the week.
-- - Compared to casual members, annual members are having more rides across the weekdays except the weekends.

-- %% [markdown]
-- ![Distribution of the Bike Type Across the Best Performing Months.png](attachment:DistributionoftheBikeTypeAcrosstheBestPerformingMonths.png)

-- %% [markdown]
-- - Classic bikes are the most preferred type of bike among the riders.
-- - Also we can see that annual members do not use docked bikes.

-- %% [markdown]
-- ![Screenshot 2022-08-12 160504.png](attachment:Screenshot2022-08-12160504.png)

-- %% [markdown]
-- > ## **Worst performing months**

-- %% [markdown]
-- ![No.of Rides Across the Worst Performing Months.png](attachment:No.ofRidesAcrosstheWorstPerformingMonths.png)

-- %% [markdown]
-- ## **Suggestions**

-- %% [markdown]
-- Here are the suggestions I would like to provide based on my analysis.

-- %% [markdown]
-- 1. The company should focus on increasing the number of rides across the best routes. They can assign more bikes at these stations having the most number of rides.
-- 2. The docked bikes are not being used by the annual members. The company can include the electric and docked bikes in the annual membership so that if the casual members want to ride these they should take the annual membership.
-- 3. Also, casual members should be given a limited number of rides in a day or a month. Annual members should be provided an unlimited number of rides.
-- 4. Make sure that there are enough bikes during the weekends since weekends will have the most number of rides.

-- %% [markdown]
-- ### **Thank You**
